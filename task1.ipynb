# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\WELCOME\\Downloads\\SalaryMulti.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Total Experience            1000 non-null   int64
#  1   Team Lead Experience        1000 non-null   int64
#  2   Project Manager Experience  1000 non-null   int64
#  3   Certifications              1000 non-null   int64
#  4   Salary                      1000 non-null   float64
# dtypes: float64(1), int64(4)
# memory usage: 39.2 KB

# %%
df.corr()
# Out:
#                             Total Experience  Team Lead Experience  \
# Total Experience                    1.000000              0.652856
# Team Lead Experience                0.652856              1.000000
# Project Manager Experience          0.477662             -0.100659
# Certifications                     -0.019265             -0.029226
# Salary                              0.941849              0.753772
#
#                             Project Manager Experience  Certifications  \
# Total Experience                              0.477662       -0.019265
# Team Lead Experience                         -0.100659       -0.029226
# Project Manager Experience                    1.000000        0.015441
# Certifications                                0.015441        1.000000
# Salary                                        0.405786        0.009678
#
#                               Salary
# Total Experience            0.941849
# Team Lead Experience        0.753772
# ...

# %%
df.head()
# Out:
#    Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                 7                     2                           4
# 1                 4                     0                           2
# 2                13                     4                           8
# 3                11                     3                           2
# 4                 8                     1                           6
#
#    Certifications         Salary
# 0               1   77318.070547
# 1               3   64951.950980
# 2               3  106058.185204
# 3               1   89649.944851
# 4               3   82206.019687

# %%
df.dtypes
# Out:
# Total Experience                int64
# Team Lead Experience            int64
# Project Manager Experience      int64
# Certifications                  int64
# Salary                        float64
# dtype: object

# %%
plt.scatter(df['Team Lead Experience'],df['Salary'])

# %%
plt.scatter(df['Total Experience'],df['Salary'])

# %%
plt.scatter(df['Project Manager Experience'],df['Salary'])

# %%
plt.scatter(df['Certifications'],df['Salary'])

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
x=df[['Total Experience','Team Lead Experience','Project Manager Experience','Certifications']]
x
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                   7                     2                           4
# 1                   4                     0                           2
# 2                  13                     4                           8
# 3                  11                     3                           2
# 4                   8                     1                           6
# ..                ...                   ...                         ...
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications
# 0                 1
# 1                 3
# 2                 3
# ...

# %%
len(x)
# Out:
# 1000

# %%
len(x[4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
y=df['Salary']
y
# Out:
# 0       77318.070547
# 1       64951.950980
# 2      106058.185204
# 3       89649.944851
# 4       82206.019687
#            ...
# 995     90941.688891
# 996     92074.890941
# 997    115914.944924
# 998     82706.285700
# 999     85347.167601
# Name: Salary, Length: 1000, dtype: float64

# %%
model= LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
slope = model.coef_
slope
# Out:
# array([2989.14710714, 1911.84860833,  989.71612906,  389.8868752 ])

# %%
intercept = model.intercept_
intercept
# Out:
# 50634.14397208563

# %%
model.predict(x)
# Out:
# array([ 79730.62233017,  65739.82528436, 106227.8404563 ,  91619.62710895,
#         83567.12683748, 105425.26025312,  68129.14313765,  77009.00208932,
#         84484.47955972,  60981.18829777,  74459.73845946,  97212.81420508,
#         92151.87271303,  82577.41070843,  74396.93456673,  65282.35475938,
#         83889.43006291,  82509.82705865,  64205.05626058,  75931.70359051,
#         67739.25626245,  58771.81494102,  86018.41247922, 106612.11147018,
#        103600.99401453,  75474.23306554,  58914.1736699 ,  92239.45508278,
#         68129.14313765,  54792.95170483,  98425.28000344,  88698.06365159,
#         75931.70359051, 113604.90029053,  93364.33851139,  83729.48428634,
#         55182.83858003,  93666.64301684,  92151.87271303,  89732.55697763,
#         89795.36087037, 108314.01769985, 112657.98933424, 116414.10290113,
#        106000.31102996,  60381.35904391, 101791.50669513,  75696.98273484,
# ...
